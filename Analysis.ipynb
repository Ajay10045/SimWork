# %%
import pandas as pd

# write code to make a connection to sqllite /Users/ajaynehra/Desktop/projects/SimWork/scenarios/checkout_conversion_drop/tables/scenario.db
import sqlite3
conn = sqlite3.connect('/Users/ajaynehra/Desktop/projects/SimWork/scenarios/checkout_conversion_drop/tables/scenario.db')   

# list the tables in the database
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)
# Out:
#                       name
# 0                documents
# 1                    users
# 2              restaurants
# 3               menu_items
# 4                   orders
# 5              order_items
# 6                  drivers
# 7                 payments
# 8            funnel_events
# 9                  reviews
# 10         support_tickets
# 11            ux_changelog
# 12             deployments
# 13         service_metrics
# 14  payment_errors_summary

# %%
documents = pd.read_sql_query("SELECT * FROM documents;", conn)
print(documents.head())
# Out:
#                      name                                            content
# 0      usability_study.md  # ZaikaNow Checkout & UPI Reliability Study\n\...
# 1  system_architecture.md  # ZaikaNow System Architecture\n\n## Overview\...

# %% [markdown]
# # Analyst

# %%
users = pd.read_sql_query("SELECT * FROM users;", conn)
print(users.head())
# Out:
#   user_id            name                        email          phone  \
# 0  U00001      Aman Gupta      aman.gupta1@zaikanow.in  +918906402157
# 1  U00002  Lakshmi Tiwari  lakshmi.tiwari2@zaikanow.in  +918170484433
# 2  U00003     Meera Verma     meera.verma3@zaikanow.in  +919476477323
# 3  U00004   Anjali Sharma   anjali.sharma4@zaikanow.in  +916924765563
# 4  U00005   Arvind Saxena   arvind.saxena5@zaikanow.in  +919466589567
#
#         city         area signup_date platform  user_type
# 0  bengaluru   HSR Layout  2023-06-09  android        new
# 1  bengaluru   Whitefield  2023-12-28      ios        new
# 2  delhi_ncr  Indirapuram  2024-03-08  android     casual
# 3  hyderabad   Gachibowli  2023-08-30  android     casual
# 4  bengaluru   Whitefield  2024-02-15      ios  returning

# %%
restaurants = pd.read_sql_query("SELECT * FROM restaurants;", conn)
print(restaurants.head())
# Out:
#   restaurant_id              name  cuisine_type       city         area  \
# 0         R0001     Punjabi Tadka  north_indian  bengaluru    Jayanagar
# 1         R0002  Tandoor Junction  north_indian  bengaluru   Whitefield
# 2         R0003       Dosa Darbar  south_indian  bengaluru  Indiranagar
# 3         R0004   Anna Idli House  south_indian  bengaluru   HSR Layout
# 4         R0005  Biryani Junction       biryani  bengaluru  Indiranagar
#
#    rating
# 0     4.6
# 1     4.4
# 2     4.3
# 3     4.0
# 4     4.7

# %%
menu_items = pd.read_sql_query("SELECT * FROM menu_items;", conn)
print(menu_items.head())
# Out:
#    item_id restaurant_id             name  \
# 0  MI00001         R0001  Paneer Lababdar
# 1  MI00002         R0001      Butter Naan
# 2  MI00003         R0001   Butter Chicken
# 3  MI00004         R0001        Veg Thali
# 4  MI00005         R0001      Dal Makhani
#
#                                   description  price
# 0         Rich tomato gravy with paneer cubes    289
# 1      Tandoor-baked naan brushed with butter     49
# 2   Creamy tomato gravy with tandoori chicken    329
# 3  North Indian combo meal with roti and rice    269
# 4       Slow-cooked black lentils with butter    249

# %%
orders = pd.read_sql_query("SELECT * FROM orders;", conn)
print(orders.head())
# Out:
#     order_id user_id restaurant_id order_status total_amount  \
# 0  ORD000001  U00870         R0052    completed       725.04
# 1  ORD000002  U02118         R0001    completed       241.30
# 2  ORD000003  U02763         R0089    completed       364.84
# 3  ORD000004  U00834         R0011    completed       638.94
# 4  ORD000005  U00909         R0032    completed       760.59
#
#             created_at
# 0  2024-10-01 21:03:15
# 1  2024-10-01 19:15:24
# 2  2024-10-01 12:14:44
# 3  2024-10-01 20:50:23
# 4  2024-10-01 20:17:53

# %%
order_items = pd.read_sql_query("SELECT * FROM order_items;", conn)
print(order_items.head())
# Out:
#   order_item_id   order_id  item_id  quantity
# 0      OI000001  ORD000001  MI00231         1
# 1      OI000002  ORD000001  MI00231         1
# 2      OI000003  ORD000001  MI00231         3
# 3      OI000004  ORD000002  MI00004         1
# 4      OI000005  ORD000002  MI00002         1

# %%
drivers = pd.read_sql_query("SELECT * FROM drivers;", conn)
print(drivers.head())
# Out:
#   driver_id           name          phone       city availability_status
# 0     D0001   Vivaan Patel  +918073964463     mumbai         on_delivery
# 1     D0002  Nandini Joshi  +916678745398  hyderabad             offline
# 2     D0003   Varun Sharma  +918906451334  bengaluru           available
# 3     D0004     Diya Reddy  +919330996184  bengaluru           available
# 4     D0005   Sakshi Menon  +919194778677  bengaluru           available

# %%
payments = pd.read_sql_query("SELECT * FROM payments;", conn)
print(payments.head())
# Out:
#   payment_id   order_id      method      provider   status  amount  \
# 0  PAY000001  ORD000001         upi  rupeeflow_v2  success  725.04
# 1  PAY000002  ORD000002      wallet  rupeeflow_v2  success  241.30
# 2  PAY000003  ORD000003         upi  rupeeflow_v2  success  364.84
# 3  PAY000004  ORD000004         upi  rupeeflow_v2  success  638.94
# 4  PAY000005  ORD000005  debit_card  rupeeflow_v2  success  760.59
#
#    processing_time_ms error_code           created_at
# 0                 714             2024-10-01 21:03:15
# 1                1121             2024-10-01 19:15:24
# 2                 676             2024-10-01 12:14:44
# 3                 684             2024-10-01 20:50:23
# 4                 906             2024-10-01 20:17:53

# %%
funnel_events = pd.read_sql_query("SELECT * FROM funnel_events;", conn)
print(funnel_events.head())
# Out:
#    event_id user_id session_id       event_type platform     device  \
# 0  E0000001  U01468   S0000001         app_open  android    Pixel 8
# 1  E0000002  U01468   S0000001  restaurant_view  android    Pixel 8
# 2  E0000003  U01013   S0000002         app_open      ios  iPhone SE
# 3  E0000004  U01013   S0000002  restaurant_view      ios  iPhone SE
# 4  E0000005  U01013   S0000002      add_to_cart      ios  iPhone SE
#
#   app_version            timestamp
# 0       8.4.1  2024-10-01 18:02:47
# 1       8.4.1  2024-10-01 18:03:38
# 2       8.4.1  2024-10-01 20:21:53
# 3       8.4.1  2024-10-01 20:22:46
# 4       8.4.1  2024-10-01 20:23:27

# %% [markdown]
# # UI-UX Agent

# %%
reviews = pd.read_sql_query("SELECT * FROM reviews;", conn)
print(reviews.head())
# Out:
#   review_id user_id   order_id  rating  \
# 0   REV0002  U02181  ORD001387       4
# 1   REV0010  U02671  ORD001675       4
# 2   REV0001  U00164  ORD002221       5
# 3   REV0013  U02924  ORD002474       5
# 4   REV0024  U01556  ORD004383       3
#
#                                                 text           created_at
# 0  Loved the breakfast combo from Anna Idli House...  2024-10-07 08:19:31
# 1  Nice app. The cart flow is smooth and the offe...  2024-10-07 22:33:14
# 2  Delivery was quick and the biryani arrived pip...  2024-10-10 01:23:25
# 3  Delivery was quick and the biryani arrived pip...  2024-10-12 22:47:28
# 4  Search feels a bit cluttered, but the order ex...  2024-10-19 23:49:50

# %%
support_tickets = pd.read_sql_query("SELECT * FROM support_tickets;", conn)
print(support_tickets.head())
# Out:
#   ticket_id user_id   order_id  category    subcategory  \
# 0    TK0001  U02888  ORD015295     promo   coupon_issue
# 1    TK0002  U01021  ORD003093  delivery  late_delivery
# 2    TK0003  U01954  ORD005275     promo   coupon_issue
# 3    TK0004  U00966  ORD029485     promo   coupon_issue
# 4    TK0005  U01286  ORD013584   payment  money_debited
#
#                                          description  priority       status  \
# 0     Republic Day coupon did not apply on checkout.       low     resolved
# 1  Delivery was very late today even though the a...    medium     resolved
# 2     Republic Day coupon did not apply on checkout.       low     resolved
# 3     Republic Day coupon did not apply on checkout.       low  in_progress
# 4  Amount got debited but the order was not confi...  critical     resolved
#
#             created_at          resolved_at
# 0  2024-12-20 13:59:00  2024-12-21 01:59:00
# 1  2024-12-26 15:43:00  2024-12-27 02:43:00
# 2  2024-12-29 17:21:00  2024-12-29 23:21:00
# 3  2025-01-01 21:49:00
# 4  2025-01-10 08:17:00  2025-01-11 05:17:00

# %%
ux_changelog = pd.read_sql_query("SELECT * FROM ux_changelog;", conn)
print(ux_changelog.head())
# Out:
#          date change_type                                        description  \
# 0  2024-12-18     feature  Added cuisine shortcuts for breakfast and biryani
# 1  2024-12-27     feature               New Year offer rail on the home feed
# 2  2025-01-05     ab_test               Testing a denser cart summary layout
# 3  2025-01-08     feature       Updated restaurant ranking for repeat orders
# 4  2025-01-10     feature   New payment success animation after confirmation
#
#   affected_area platform
# 0      homepage      all
# 1      homepage      all
# 2          cart      all
# 3        search      all
# 4      checkout      all

# %% [markdown]
# # Engineering lead

# %%
deployments = pd.read_sql_query("SELECT * FROM deployments;", conn)
print(deployments.head())
# Out:
#   deploy_id               service  \
# 0    DEP001       catalog_service
# 1    DEP002  notification_service
# 2    DEP003        search_service
# 3    DEP004       payment_service
# 4    DEP005      checkout_service
#
#                                          description        author  \
# 0    Expanded breakfast collections for metro cities   ananya.iyer
# 1               New Year reminder campaign scheduler  rahul.sharma
# 2  Restaurant ranking refresh for repeat-order in...   varun.reddy
# 3     Migrated to RupeeFlow v3 payment orchestration    priya.nair
# 4          Retry copy tweak on payment review screen   meera.joshi
#
#              timestamp rollback_available commit_hash
# 0  2024-12-18 09:45:00                yes     e5634e3
# 1  2024-12-28 13:10:00                yes     049a69d
# 2  2025-01-08 07:30:00                yes     29990e6
# 3  2025-01-10 06:00:00                yes     2075f8c
# 4  2025-01-12 11:20:00                yes     d8f5a8e

# %%
service_metrics = pd.read_sql_query("SELECT * FROM service_metrics;", conn)
print(service_metrics.head())
# Out:
#          date               service  p50_ms  p95_ms  p99_ms  error_rate_pct  \
# 0  2024-10-01       payment_service     141     305     447            0.38
# 1  2024-10-01      checkout_service      89     213     331            0.12
# 2  2024-10-01       catalog_service      46     128     219            0.07
# 3  2024-10-01          user_service      36      87     166            0.10
# 4  2024-10-01  notification_service      49     149     258            0.09
#
#    error_count  request_count
# 0           82          21842
# 1           30          25663
# 2           38          55667
# 3           33          33382
# 4           10          11333

# %%
payment_errors_summary = pd.read_sql_query("SELECT * FROM payment_errors_summary;", conn)
print(payment_errors_summary.head())
# Out:
#          date              error_code  count payment_method
# 0  2024-10-01            BANK_TIMEOUT      1     debit_card
# 1  2024-10-01  PAYMENT_PROVIDER_ERROR      1    credit_card
# 2  2024-10-01  PAYMENT_PROVIDER_ERROR      2     debit_card
# 3  2024-10-01  PAYMENT_PROVIDER_ERROR      6            upi
# 4  2024-10-01  PAYMENT_PROVIDER_ERROR      2         wallet
